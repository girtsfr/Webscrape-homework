# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
test = requests.get("https://tradingeconomics.com/")
soup = BeautifulSoup(test.content, "lxml")
tabulas = soup.find_all("table")[9]
d = pd.read_html(str(tabulas))
print(d[0].to_json)
# Out:
# <bound method NDFrame.to_json of    COUNTRIES WORLD AMERICA EUROPE ASIA AUSTRALIA AFRICA    GDP  GDP YoY  \
# 0                                       United States    20937    0.40%
# 1                                               China    14723    7.90%
# 2                                           Euro Area    12933   -1.30%
# 3                                               Japan     5065   -1.60%
# 4                                             Germany     3806   -3.10%
# 5                                      United Kingdom     2708   -6.10%
# 6                                               India     2623    1.60%
# 7                                              France     2603    1.20%
# 8                                               Italy     1886   -0.80%
# 9                                              Canada     1643    0.30%
# 10                                        South Korea     1631    1.90%
# 11                                             Russia     1484   -0.70%
# ...
